# %% [markdown]
# <a href="https://colab.research.google.com/github/jisong3266/Python_practice/blob/main/day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.7.22)

# %%
import folium
m = folium.Map(location=[37.547631, 126.942463], zoom_start=15)
folium.Marker([37.547631, 126.942463]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_893c8a559cb256b4fa0121718eb7a0ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_893c8a559cb256b4fa0121718eb7a0ac = L.map(
#                 &quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot;,
#                 {
#                     center: [37.547631, 126.942463],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f3ddad5ca9a3ee6681c1d0d131e9605 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var marker_dbb2a9cd4684b3504a075bcb31653c6f = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([37.54392611998678, 126.95105440539045], popup='subway').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_893c8a559cb256b4fa0121718eb7a0ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_893c8a559cb256b4fa0121718eb7a0ac = L.map(
#                 &quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot;,
#                 {
#                     center: [37.547631, 126.942463],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f3ddad5ca9a3ee6681c1d0d131e9605 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var marker_dbb2a9cd4684b3504a075bcb31653c6f = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var marker_1b6b47aee364ae9ed167f58c9c87fa59 = L.marker(
#                 [37.54392611998678, 126.95105440539045],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#         var popup_ac746512e5b1f54dc657dfb3ebaf7bbd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e98c734e6795fa7e90ef88bd23b1c027 = $(`&lt;div id=&quot;html_e98c734e6795fa7e90ef88bd23b1c027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_ac746512e5b1f54dc657dfb3ebaf7bbd.setContent(html_e98c734e6795fa7e90ef88bd23b1c027);
#
#
#
#         marker_1b6b47aee364ae9ed167f58c9c87fa59.bindPopup(popup_ac746512e5b1f54dc657dfb3ebaf7bbd)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([37.53959008903884, 126.94590610865076], popup='subway', tooltip='마포역').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_893c8a559cb256b4fa0121718eb7a0ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_893c8a559cb256b4fa0121718eb7a0ac = L.map(
#                 &quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot;,
#                 {
#                     center: [37.547631, 126.942463],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f3ddad5ca9a3ee6681c1d0d131e9605 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var marker_dbb2a9cd4684b3504a075bcb31653c6f = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var marker_1b6b47aee364ae9ed167f58c9c87fa59 = L.marker(
#                 [37.54392611998678, 126.95105440539045],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#         var popup_ac746512e5b1f54dc657dfb3ebaf7bbd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e98c734e6795fa7e90ef88bd23b1c027 = $(`&lt;div id=&quot;html_e98c734e6795fa7e90ef88bd23b1c027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_ac746512e5b1f54dc657dfb3ebaf7bbd.setContent(html_e98c734e6795fa7e90ef88bd23b1c027);
#
#
#
#         marker_1b6b47aee364ae9ed167f58c9c87fa59.bindPopup(popup_ac746512e5b1f54dc657dfb3ebaf7bbd)
#         ;
#
#
#
#
#             var marker_ee2c85f44446326d3621863de09c88af = L.marker(
#                 [37.53959008903884, 126.94590610865076],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#         var popup_14e4537dacc651e3aff9d546851e5943 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97f6347f70e663b1ac09e8e284ca8ac8 = $(`&lt;div id=&quot;html_97f6347f70e663b1ac09e8e284ca8ac8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_14e4537dacc651e3aff9d546851e5943.setContent(html_97f6347f70e663b1ac09e8e284ca8ac8);
#
#
#
#         marker_ee2c85f44446326d3621863de09c88af.bindPopup(popup_14e4537dacc651e3aff9d546851e5943)
#         ;
#
#
#
#
#             marker_ee2c85f44446326d3621863de09c88af.bindTooltip(
#                 `&lt;div&gt;
#                      마포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#공덕역
folium.Marker([37.54392611998678, 126.95105440539045], popup='subway', icon=folium.Icon(color='black', icon='info-sign')).add_to(m)
#마포역
folium.Marker([37.53959008903884, 126.94590610865076], popup='subway', tooltip='마포역', icon=folium.Icon(color='lightblue', icon='fa-solid fa-train-subway', prefix='fa-solid')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_893c8a559cb256b4fa0121718eb7a0ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_893c8a559cb256b4fa0121718eb7a0ac = L.map(
#                 &quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot;,
#                 {
#                     center: [37.547631, 126.942463],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f3ddad5ca9a3ee6681c1d0d131e9605 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var marker_dbb2a9cd4684b3504a075bcb31653c6f = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var marker_1b6b47aee364ae9ed167f58c9c87fa59 = L.marker(
#                 [37.54392611998678, 126.95105440539045],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#         var popup_ac746512e5b1f54dc657dfb3ebaf7bbd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e98c734e6795fa7e90ef88bd23b1c027 = $(`&lt;div id=&quot;html_e98c734e6795fa7e90ef88bd23b1c027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_ac746512e5b1f54dc657dfb3ebaf7bbd.setContent(html_e98c734e6795fa7e90ef88bd23b1c027);
#
#
#
#         marker_1b6b47aee364ae9ed167f58c9c87fa59.bindPopup(popup_ac746512e5b1f54dc657dfb3ebaf7bbd)
#         ;
#
#
#
#
#             var marker_ee2c85f44446326d3621863de09c88af = L.marker(
#                 [37.53959008903884, 126.94590610865076],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#         var popup_14e4537dacc651e3aff9d546851e5943 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97f6347f70e663b1ac09e8e284ca8ac8 = $(`&lt;div id=&quot;html_97f6347f70e663b1ac09e8e284ca8ac8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_14e4537dacc651e3aff9d546851e5943.setContent(html_97f6347f70e663b1ac09e8e284ca8ac8);
#
#
#
#         marker_ee2c85f44446326d3621863de09c88af.bindPopup(popup_14e4537dacc651e3aff9d546851e5943)
#         ;
#
#
#
#
#             marker_ee2c85f44446326d3621863de09c88af.bindTooltip(
#                 `&lt;div&gt;
#                      마포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5117cf2c123195c9f0aec2e355d90c1d = L.marker(
#                 [37.54392611998678, 126.95105440539045],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var icon_91f5799124a92a304ce8b25bae00b63e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5117cf2c123195c9f0aec2e355d90c1d.setIcon(icon_91f5799124a92a304ce8b25bae00b63e);
#
#
#         var popup_d60eb30fc5b3e00dd1093b2dad64ed56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c1373f108644fc732aa939e1e26398e = $(`&lt;div id=&quot;html_7c1373f108644fc732aa939e1e26398e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_d60eb30fc5b3e00dd1093b2dad64ed56.setContent(html_7c1373f108644fc732aa939e1e26398e);
#
#
#
#         marker_5117cf2c123195c9f0aec2e355d90c1d.bindPopup(popup_d60eb30fc5b3e00dd1093b2dad64ed56)
#         ;
#
#
#
#
#             var marker_36ae136c9e6f330a7c8e83f571739ad6 = L.marker(
#                 [37.53959008903884, 126.94590610865076],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var icon_203bbd1c503ebc40c112294867bae988 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-train-subway&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_36ae136c9e6f330a7c8e83f571739ad6.setIcon(icon_203bbd1c503ebc40c112294867bae988);
#
#
#         var popup_3fa51b33d7b2c639332047e44dcf474d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %%
# CircleMarker
folium.CircleMarker([37.54392611998678, 126.95105440539045], radius=100, color='#34EBC6', fill_color='#blue', popup='CircleMarker', tooltip='tooltip').add_to(m)
# Circle
folium.Circle([37.54392611998678, 126.95105440539045], radius=100, color='#EB9E34', fill_color='red', popup='Circle', tooltip='tooltip').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_893c8a559cb256b4fa0121718eb7a0ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_893c8a559cb256b4fa0121718eb7a0ac = L.map(
#                 &quot;map_893c8a559cb256b4fa0121718eb7a0ac&quot;,
#                 {
#                     center: [37.547631, 126.942463],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f3ddad5ca9a3ee6681c1d0d131e9605 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var marker_dbb2a9cd4684b3504a075bcb31653c6f = L.marker(
#                 [37.547631, 126.942463],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var marker_1b6b47aee364ae9ed167f58c9c87fa59 = L.marker(
#                 [37.54392611998678, 126.95105440539045],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#         var popup_ac746512e5b1f54dc657dfb3ebaf7bbd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e98c734e6795fa7e90ef88bd23b1c027 = $(`&lt;div id=&quot;html_e98c734e6795fa7e90ef88bd23b1c027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_ac746512e5b1f54dc657dfb3ebaf7bbd.setContent(html_e98c734e6795fa7e90ef88bd23b1c027);
#
#
#
#         marker_1b6b47aee364ae9ed167f58c9c87fa59.bindPopup(popup_ac746512e5b1f54dc657dfb3ebaf7bbd)
#         ;
#
#
#
#
#             var marker_ee2c85f44446326d3621863de09c88af = L.marker(
#                 [37.53959008903884, 126.94590610865076],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#         var popup_14e4537dacc651e3aff9d546851e5943 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97f6347f70e663b1ac09e8e284ca8ac8 = $(`&lt;div id=&quot;html_97f6347f70e663b1ac09e8e284ca8ac8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_14e4537dacc651e3aff9d546851e5943.setContent(html_97f6347f70e663b1ac09e8e284ca8ac8);
#
#
#
#         marker_ee2c85f44446326d3621863de09c88af.bindPopup(popup_14e4537dacc651e3aff9d546851e5943)
#         ;
#
#
#
#
#             marker_ee2c85f44446326d3621863de09c88af.bindTooltip(
#                 `&lt;div&gt;
#                      마포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5117cf2c123195c9f0aec2e355d90c1d = L.marker(
#                 [37.54392611998678, 126.95105440539045],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var icon_91f5799124a92a304ce8b25bae00b63e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5117cf2c123195c9f0aec2e355d90c1d.setIcon(icon_91f5799124a92a304ce8b25bae00b63e);
#
#
#         var popup_d60eb30fc5b3e00dd1093b2dad64ed56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c1373f108644fc732aa939e1e26398e = $(`&lt;div id=&quot;html_7c1373f108644fc732aa939e1e26398e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;subway&lt;/div&gt;`)[0];
#                 popup_d60eb30fc5b3e00dd1093b2dad64ed56.setContent(html_7c1373f108644fc732aa939e1e26398e);
#
#
#
#         marker_5117cf2c123195c9f0aec2e355d90c1d.bindPopup(popup_d60eb30fc5b3e00dd1093b2dad64ed56)
#         ;
#
#
#
#
#             var marker_36ae136c9e6f330a7c8e83f571739ad6 = L.marker(
#                 [37.53959008903884, 126.94590610865076],
#                 {}
#             ).addTo(map_893c8a559cb256b4fa0121718eb7a0ac);
#
#
#             var icon_203bbd1c503ebc40c112294867bae988 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-train-subway&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_36ae136c9e6f330a7c8e83f571739ad6.setIcon(icon_203bbd1c503ebc40c112294867bae988);
#
#
#         var popup_3fa51b33d7b2c639332047e44dcf474d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %%
import pandas as pd
data = pd.read_csv("/content/택시승차대 현황.csv", encoding='cp949')
m = folium.Map()
for i in range(11):
  folium.Marker([data['위도'][i],data['경도'][i]], tooltip=data['위치명'][i],icon=folium.Icon(color='red', icon='fa-solid fa-taxi', prefix='fa-solid')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a0471af2ab6ecf728b2356749bb49e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a0471af2ab6ecf728b2356749bb49e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a0471af2ab6ecf728b2356749bb49e1 = L.map(
#                 &quot;map_9a0471af2ab6ecf728b2356749bb49e1&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43152cc50def23dabbdce888980e282c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a0471af2ab6ecf728b2356749bb49e1);
#
#
#             var marker_8e70e20a90ac3b4d1739e0b7d5fbdd7d = L.marker(
#                 [37.5453970345156, 126.952564116178],
#                 {}
#             ).addTo(map_9a0471af2ab6ecf728b2356749bb49e1);
#
#
#             var icon_bd88c6e3f25e8f0f4b62391603c84539 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_8e70e20a90ac3b4d1739e0b7d5fbdd7d.setIcon(icon_bd88c6e3f25e8f0f4b62391603c84539);
#
#
#             marker_8e70e20a90ac3b4d1739e0b7d5fbdd7d.bindTooltip(
#                 `&lt;div&gt;
#                      신용보증기금 마포지점 앞
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2003c9b8b746a83833318ac66c5d4042 = L.marker(
#                 [37.5520005467366, 126.95651212572],
#                 {}
#             ).addTo(map_9a0471af2ab6ecf728b2356749bb49e1);
#
#
#             var icon_63f4e505522503ce9102046190388ef1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_2003c9b8b746a83833318ac66c5d4042.setIcon(icon_63f4e505522503ce9102046190388ef1);
#
#
#             marker_2003c9b8b746a83833318ac66c5d4042.bindTooltip(
#                 `&lt;div&gt;
#                      마포SK허브 빌딩 앞
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_472ce2e3b4942db9d88b037c0a92e609 = L.marker(
#                 [37.541448169111, 126.947232985498],
#                 {}
#             ).addTo(map_9a0471af2ab6ecf728b2356749bb49e1);
#
#
#             var icon_844cc1883644a4bf1c2ba9613c229327 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_472ce2e3b4942db9d88b037c0a92e609.setIcon(icon_844cc1883644a4bf1c2ba9613c229327);
#
#
#             marker_472ce2e3b4942db9d88b037c0a92e609.bindTooltip(
#                 `&lt;div&gt;
#                      트라팰리스빌딩 앞
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_af0db94c6053e6ff92f108fdceda9012 = L.marker(
#                 [37.5484275320782, 126.916896449905],
#                 {}
#             ).addTo(map_9a0471af2ab6ecf728b2356749bb49e1);
#
#
#             var icon_fa2bb14dcece3d12595a92f7abd8a7d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_af0db94c6053e6ff92f108fdceda9012.setIcon(icon_fa2bb14dcece3d12595a92f7abd8a7d8);
#
#
#             marker_af0db94c6053e6ff92f108fdceda9012.bindTooltip(
#                 `&lt;div&gt;
#                      주식회사 메칸더브이 앞(혜당한방병원 건너)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_876f11e9af4f608bc24c317dbadd84ff = L.marker(
#                 [37.55371161031, 126.935188539995],
#                 {}
#             ).addTo(map_9a0471af2ab6ecf728b2356749bb49e1);
#
#
#             var icon_8880d958d59bc99cec94cbb57a71d30d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;:
